# %%
# %matplotlib notebook

# %%
from close_packings import *
from cubic_crystal_systems import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23676/3476207853.py in <module>
# ----> 1 from close_packings import *
#       2 from cubic_crystal_systems import *
#
# ~\OneDrive\Documents\KU\commutative-grid\materials\close_packings.py in <module>
#       9 from math import sqrt
#      10 from matplotlib import pyplot as plt
# ---> 11 from cubic_crystal_systems import simple_cubic,crystal_system
#      12
#      13 class face_centered_cubic(simple_cubic):
#
# ~\OneDrive\Documents\KU\commutative-grid\materials\cubic_crystal_systems.py in <module>
#       8 import numpy as np
#       9 from matplotlib import pyplot as plt
# ---> 10 from sklearn.metrics.pairwise import euclidean_distances
#      11
#      12 class crystal_system:
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
fcc=face_centered_cubic(num_cells_axis=2)
hcp=hexagonal_close_packing(2)

# %%
print(len(fcc),len(hcp))

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
fcc.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hcp.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
