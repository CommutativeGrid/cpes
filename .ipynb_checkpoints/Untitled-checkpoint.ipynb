# %%
# %matplotlib notebook

# %%
from data_toy_model import *

# %%
a=face_centered_cubic(4)
b=body_centered_cubic(5)

# %%
print(len(a),len(b))
# Out:
# 365 341

# %%
a.data
# Out:
# array([[0. , 0. , 0. ],
#        [0. , 0. , 1. ],
#        [0. , 0. , 2. ],
#        ...,
#        [3.5, 1.5, 4. ],
#        [3.5, 2.5, 4. ],
#        [3.5, 3.5, 4. ]])

# %%
a.plot_3d()
# Out:
# <img src="data:image/png;base64,..." width="640">
