# %%
# %matplotlib notebook

# %%
from close_packings_via_layers import face_centered_cubic as v1
from close_packings_via_layers import hexagonal_close_packing as h1
from close_packings import face_centered_cubic as v2
from close_packings import hexagonal_close_packing as h2
from sklearn.metrics.pairwise import euclidean_distances

# %%
q1.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
q1=h1(5)
q2=h2(5,sphere_radius=0.5)

# %%
fcc=face_centered_cubic(num_vector=(7,7,3))
hcp=hexagonal_close_packing(3)
# Out:
# Parameter num is ignored. Using num_vector instead.
