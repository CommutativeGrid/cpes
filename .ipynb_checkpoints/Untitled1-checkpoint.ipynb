# %%
# %matplotlib notebook

# %%
from close_packings_via_layers import *

# %%
fcc=face_centered_cubic(5)
hcp=hexagonal_close_packing(3)

# %%
fcc.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
